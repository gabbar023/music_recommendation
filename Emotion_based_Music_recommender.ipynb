# %%
import pandas as pd

# %%
data=pd.read_csv('tracks.csv')
data
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
data.drop_duplicates(inplace=True,subset=['name'])

# %%
name=data['name']

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

# %%
col_features = ["danceability","energy","loudness","speechiness","acousticness","valence"]
X = MinMaxScaler().fit_transform(data[col_features])
kmeans = KMeans(init="k-means++",n_clusters=5,random_state=15).fit(X)
data['emotion'] = kmeans.labels_

# %%
data['song_name']=name

# %%
data
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586665  0SjsIzJkZfDU7wlcdklEFR                    John Brown's Song
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
cluster=data.groupby(by=data['emotion'])

# %%
#Onehot  coding for categorical features

# %%
y=data.pop('emotion')
x=data.drop(columns=['name','artists','id','id_artists','release_date','song_name'])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

# %%
# !pip install lightgbm
from lightgbm import LGBMClassifier
model=LGBMClassifier().fit(x_train,y_train)

# %%
model.score(x_train,y_train)
# Out:
# 0.9991339567351663

# %%
y_pred=model.predict(x_test)
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_pred, y_test)
print('LightGBM Model accuracy score: {0:0.4f}'.format(accuracy_score(y_test, y_pred)))
# Out:
# LightGBM Model accuracy score: 0.9932

# %%
#check for overfitting
print('Training set score: {:.4f}'.format(model.score(x_train, y_train)))

print('Test set score: {:.4f}'.format(model.score(x_test, y_test)))
# Out:
# Training set score: 0.9991
# Test set score: 0.9932

# %%
#classfication metrics
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99     40175
#            1       0.99      1.00      1.00     50928
#            2       0.99      0.99      0.99      9773
#            3       0.99      0.99      0.99     37982
#            4       0.99      0.99      0.99     39732
#
#     accuracy                           0.99    178590
#    macro avg       0.99      0.99      0.99    178590
# weighted avg       0.99      0.99      0.99    178590

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print('Confusion matrix\n\n', cm)
print('\nTrue Positives(TP) = ', cm[0,0])
print('\nTrue Negatives(TN) = ', cm[1,1])
print('\nFalse Positives(FP) = ', cm[0,1])
print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[39889   144    20    50    72]
#  [  133 50693    18     0    84]
#  [   15     9  9702    15    32]
#  [   71     0    13 37733   165]
#  [   42   113    30   183 39364]]
#
# True Positives(TP) =  39889
#
# True Negatives(TN) =  50693
#
# False Positives(FP) =  144
#
# False Negatives(FN) =  133

# %%
import lightgbm
import matplotlib.pyplot as plt
ax = lightgbm.plot_importance(model, max_num_features=10, figsize=(15,15))
plt.show()

# %%
df=cluster.apply(lambda x: x.sort_values(["energy"],ascending=False))
df.reset_index(level=0, inplace=True)

# %%
# !pip install keras
# !pip install imutils
from keras.preprocessing.image import img_to_array
import imutils
from keras.models import load_model
import numpy as np
import cv2

# %%
detection_model_path = 'haarcascade_frontalface_default.xml'
emotion_model_path = 'inception_resnet_final.h5'
face_detection = cv2.CascadeClassifier(detection_model_path)
emotion_classifier = load_model(emotion_model_path, compile=False)
EMOTIONS = ["angry","fear", "happy","neutral","sad"]

# %%
from keras.preprocessing import image
def emotion_testing():
        cap=cv2.VideoCapture(0)
        while True:
            ret,test_img=cap.read()# captures frame and returns boolean value and captured image
            if not ret:
                continue
            gray_img= cv2.cvtColor(test_img, cv2.COLOR_BGR2GRAY)

            faces_detected = face_detection.detectMultiScale(gray_img, 1.32, 5)


            for (x,y,w,h) in faces_detected:
                cv2.rectangle(test_img,(x,y),(x+w,y+h),(255,0,0),thickness=7)
                roi_gray=gray_img[y:y+w,x:x+h]#cropping region of interest i.e. face area from  image
                roi_gray=roi_gray=cv2.resize(roi_gray,(197,197),interpolation=cv2.INTER_AREA)

                img_pixels = image.img_to_array(roi_gray)
                img_pixels = np.expand_dims(img_pixels, axis = 0)
                img_pixels /= 255

                predictions = emotion_classifier.predict(img_pixels)

                #find max indexed array
                max_index = np.argmax(predictions[0])
                predicted_emotion = EMOTIONS[max_index]

                cv2.putText(test_img, predicted_emotion, (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)

            resized_img = cv2.resize(test_img, (1000, 700))
            cv2.imshow('Facial emotion analysis ',resized_img)



            if cv2.waitKey(0) & 0xFF == ord('q'):
                     break
        cap.release()
        cv2.destroyAllWindows
        return predicted_emotion

# %%
emotion_word=emotion_testing()
if emotion_word=='sad':
    emotion_code=4
elif emotion_word=='happy':
    emotion_code=2
elif emotion_word=='angry':
    emotion_code=0
elif emotion_word=='fear':
    emotion_code=1
else:
    emotion_code=3
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 197, 197, 3) for input KerasTensor(type_spec=TensorSpec(shape=(None, 197, 197, 3), dtype=tf.float32, name='input_1'), name='input_1', description="created by layer 'input_1'"), but it was called on an input with incompatible shape (None, 197, 197, 1).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-f3de2299f764> in <module>
# ----> 1 emotion_word=emotion_testing()
#       2 if emotion_word=='sad':
#       3     emotion_code=4
#       4 elif emotion_word=='happy':
#       5     emotion_code=2
#
# <ipython-input-41-f036ba00e137> in emotion_testing()
#      20                 img_pixels /= 255
#      21
# ---> 22                 predictions = emotion_classifier.predict(img_pixels)
#      23
#      24                 #find max indexed array
#
# ...

# %%
def get_results(emotion_code):
    NUM_RECOMMEND=10
    happy_set=[]
    sad_set=[]
    Angry_set=[]
    Fear_set[=[]
    Neutral_set[]
    if emotion_code==0:
        sad_set.append(df[df['emotion']==4]['song_name'].head(NUM_RECOMMEND))
        return pd.DataFrame(sad_set).T
    elif emotion_code==1:
        happy_set.append(df[df['emotion']==2]['song_name'].head(NUM_RECOMMEND))
        return pd.DataFrame(happy_set).T
    elif emotion_code==2:
        Angry_set.append(df[df['emotion']==0]['song_name'].head(NUM_RECOMMEND))
        return pd.DataFrame(Angry_set).T
    elif emotion_code==3:
        Fear_set.append(df[df['emotion']==1['song_name'].head(NUM_RECOMMEND))
        return pd.DataFrame(Fear_set).T
    else:
        Neutral_set.append(df[df['emotion']==3]['song_name'].head(NUM_RECOMMEND))
        return pd.DataFrame(Neutral_set).T

# %%
print(get_results(emotion_code))
if emotion_word=='sad':
    print('emotion detected is SAD')
elif emotion_word=='happy':
    print('emotion detected is HAPPY')
elif emotion_word=='Angry':
    print('emotion detected is AngrY')
elif emotion_word=='Fear':
    print('emotion detected is Fear')
elif emotion_word=='Neutral':
    print('emotion detected is Neutral')
